# %%
import os
import sys
import pandas as pd
import numpy as np
from descartes import PolygonPatch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
sys.path.insert(0, os.path.dirname(os.getcwd()))
import alphashape
import open3d as o3d
from shapely.geometry import Point
from PIL import Image
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
points = o3d.io.read_point_cloud('/home/christianforeman/catkin_ws/src/plant_selector/bags/sup.pcd')
points_3d = np.asarray(points.points)
points_2d = points_3d[:, :2]
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter(points_3d[:, 0], points_3d[:, 1], points_3d[:, 2])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(points_3d[:, 0], points_3d[:, 1])
alpha_shape = alphashape.alphashape(points_2d, 650)
ax.add_patch(PolygonPatch(alpha_shape, alpha=0.2))
plt.show()
# Out:
# /home/christianforeman/catkin_ws/src/venv/lib/python3.8/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
points_2d = np.around(points_2d, 4)
min = np.amin(points_2d, axis=0)
max = np.amax(points_2d, axis=0)
rng = (10000 * (max - min)).astype(int)
img = np.zeros((rng[0], rng[1], 3), dtype=np.uint8)
x = min[0]
y = min[1]
print(rng)
for i in range(rng[0]):
    y = min[1]
    for j in range(rng[1]):
        point = Point(x, y)
        if alpha_shape.contains(point):
            img[i][j] = (255, 255, 255)
        y += 0.0001
    x += 0.0001
img_act = Image.fromarray(img, 'RGB')
img_act.show()
# Out:
# [171 184]

# %%
# calculate centroid
center = 10000 * (np.sum(points_2d, axis=0) / points_2d.shape[0] - min)
center = center.astype(int)
print(center)
# Out:
# [71 87]

# %%
import cv2 as cv

weed = np.copy(img_act)
weed = cv.cvtColor(weed, cv.COLOR_RGB2GRAY)
final_img = np.copy(img_act)
final_img = cv.cvtColor(final_img, cv.COLOR_RGB2GRAY)
size = np.size(weed)

skel = np.zeros(weed.shape, np.uint8)
element = cv.getStructuringElement(cv.MORPH_CROSS, (5, 5))
done = False

while not done:
    eroded = cv.erode(weed, element)
    temp = cv.dilate(eroded, element)
    temp = cv.subtract(weed, temp)
    skel = cv.bitwise_or(skel, temp)
    weed = eroded.copy()

    zeros = size - cv.countNonZero(weed)
    if zeros == size:
        done = True
plt.figure(3)
plt.imshow(skel, cmap='gray')
plt.title('Skeletonization'), plt.xticks([]), plt.yticks([])
                
# Add in the centroid to the image
final_img = cv.circle(final_img, (center[1], center[0]), radius=2, color=(20), thickness=-1)
final_img[np.where(final_img == 0)] = 50
final_img[np.where(final_img == 255)] = 80
final_img[np.where(skel == 255)] = 100

plt.figure(4)
plt.imshow(final_img, cmap='RdYlGn')
plt.title('Skeleton'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
alpha = alphashape.alphashape(points_2d, 500)
r = list(alpha.exterior.coords)
v = np.array(r)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(v[:, 0], v[:, 1])
ax.scatter(points_2d[:, 0], points_2d[:, 1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [76], in <cell line: 2>()
#       1 alpha = alphashape.alphashape(points_2d, 500)
# ----> 2 r = list(alpha.exterior.coords)
#       3 v = np.array(r)
#       4 fig = plt.figure()
#
# AttributeError: 'MultiPolygon' object has no attribute 'exterior'
